# %%
from dask import dataframe as dd
dask_df = dd.read_csv('C:/Users/flo/LRZ Sync+Share/multifidelity_data/rbv2_xgboost/data.csv', dtype={'f1': 'float64', 'max_depth': 'float64','trainsize': 'float64'}, blocksize =  640000000)
dask_df.set_index('task_id')
# Out:
# Dask DataFrame Structure:
#                dataset trainsize   repl   seed booster nrounds      eta    gamma   lambda    alpha subsample max_depth min_child_weight colsample_bytree colsample_bylevel rate_drop skip_drop num.impute.selected.cpo timetrain timepredict      acc      bac      auc    brier       f1  logloss   memory
# npartitions=39
# 3               object   float64  int64  int64  object   int64  float64  float64  float64  float64   float64   float64          float64          float64           float64   float64   float64                  object   float64     float64  float64  float64  float64  float64  float64  float64  float64
# 11                 ...       ...    ...    ...     ...     ...      ...      ...      ...      ...       ...       ...              ...              ...               ...       ...       ...                     ...       ...         ...      ...      ...      ...      ...      ...      ...      ...
# ...

# %%
metadf = dask_df.head(0)

def get_topn(x, n = 250000):
    return x.sample(frac=1).head(n)

# %%
dask_df2 = dd.read_csv('C:/Users/flo/LRZ Sync+Share/multifidelity_data/rbv2_xgboost/data.csv', dtype={'f1': 'float64', 'max_depth': 'float64','trainsize': 'float64'}, blocksize =  640000000)
dask_df2.set_index('task_id')
# Out:
# Dask DataFrame Structure:
#                dataset trainsize   repl   seed booster nrounds      eta    gamma   lambda    alpha subsample max_depth min_child_weight colsample_bytree colsample_bylevel rate_drop skip_drop num.impute.selected.cpo timetrain timepredict      acc      bac      auc    brier       f1  logloss   memory
# npartitions=39
# 3               object   float64  int64  int64  object   int64  float64  float64  float64  float64   float64   float64          float64          float64           float64   float64   float64                  object   float64     float64  float64  float64  float64  float64  float64  float64  float64
# 11                 ...       ...    ...    ...     ...     ...      ...      ...      ...      ...       ...       ...              ...              ...               ...       ...       ...                     ...       ...         ...      ...      ...      ...      ...      ...      ...      ...
# ...

# %%
# full = dask_df[dask_df.trainsize==1.].groupby('task_id').apply(get_topn, meta=metadf).compute()

# %%
# full.to_csv('C:/Users/flo/LRZ Sync+Share/multifidelity_data/rbv2_xgboost/data_full.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-2f747909d925> in <module>
# ----> 1 full.to_csv('C:/Users/flo/LRZ Sync+Share/multifidelity_data/rbv2_xgboost/data_full.csv')
#
# NameError: name 'full' is not defined

# %%
fid = dask_df.groupby(['task_id']).apply(get_topn, meta=metadf).compute()

# %%
fid.to_csv('C:/Users/flo/LRZ Sync+Share/multifidelity_data/rbv2_xgboost/data_fidelity.csv')
